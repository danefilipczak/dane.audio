# %%
from music21 import *
# Out:
# music21: Certain music21 functions might need the optional package scipy;
#                   if you run into errors, install it by following the instructions at
#                   http://mit.edu/music21/doc/installing/installAdditional.html

# %%
c = chord.Chord("C4 E4 G4")

# %%
c
# Out:
# <music21.chord.Chord C4 E4 G4>

# %%
c.isConsonant()
# Out:
# True

# %%
c.show()

# %%
c.show()

# %%
c.play()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-a8f532bd7dac> in <module>()
# ----> 1 c.play()
#
# AttributeError: 'Chord' object has no attribute 'play'

# %%
c.sound()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ed3f072c2eaa> in <module>()
# ----> 1 c.sound()
#
# AttributeError: 'Chord' object has no attribute 'sound'

# %%
sp = midi.realtime.StreamPlayer(c)

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2b66fd261ee5> in <module>()
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
c = chord.Chord("C4 E4 G4")

# %%
c
# Out:
# <music21.chord.Chord C4 E4 G4>

# %%
sp = midi.realtime.StreamPlayer(c)

# %%
sp.play()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d4e94ae4e690> in <module>()
# ----> 1 sp.play()
#
# /usr/local/lib/python3.6/site-packages/music21/midi/realtime.py in play(self, busyFunction, busyArgs, endFunction, endArgs, busyWaitMilliseconds)
#     124         endFunction is a function that is called with endArgs when the music finishes playing.
#     125         '''
# --> 126         streamStringIOFile = self.getStringOrBytesIOFile()
#     127         self.playStringIOFile(streamStringIOFile, busyFunction, busyArgs,
#     128                               endFunction, endArgs, busyWaitMilliseconds)
#
# /usr/local/lib/python3.6/site-packages/music21/midi/realtime.py in getStringOrBytesIOFile(self)
#     129
#     130     def getStringOrBytesIOFile(self):
# --> 131         streamMidiFile = midiTranslate.streamToMidiFile(self.streamIn)
#     132         streamMidiWritten = streamMidiFile.writestr()
#     133         return StrByIO(streamMidiWritten)
#
# /usr/local/lib/python3.6/site-packages/music21/midi/translate.py in streamToMidiFile(inputM21)
#    1915
#    1916     s = inputM21
# -> 1917     midiTracks = streamHierarchyToMidiTracks(s)
#    1918
#    1919     # update track indices
#
# /usr/local/lib/python3.6/site-packages/music21/midi/translate.py in streamHierarchyToMidiTracks(inputM21, acceptableChannelList)
#    1698
#    1699     # makes a deepcopy
# -> 1700     s = _prepareStreamForMidi(inputM21)
#    1701
#    1702     # return a list of MidiTrack objects
#
# /usr/local/lib/python3.6/site-packages/music21/midi/translate.py in _prepareStreamForMidi(s)
#    1656
#    1657     s = copy.deepcopy(s)
# -> 1658     if s.hasPartLikeStreams():
#    1659         # check for tempo indications in the score
#    1660         mmTopLevel = s.iter.getElementsByClass('MetronomeMark').stream()
#
# AttributeError: 'Chord' object has no attribute 'hasPartLikeStreams'

# %%
>>> b = corpus.parse('bwv66.6')
>>> 
>>> sp = midi.realtime.StreamPlayer(b)
>>> sp.play()

# %%
b.show()

# %%
sp.play()
